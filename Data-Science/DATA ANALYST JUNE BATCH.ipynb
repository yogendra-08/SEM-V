# %% [markdown]
# # OPERATORS

# %%
a = 1
b = 2

c = a+b

print(c)
# Out:
# 3

# %%
a = 1
b = 2

c = a-b

print(c)
# Out:
# -1

# %%
a = 1
b = 2

c = a*b

print(c)
# Out:
# 2

# %%
a = 1
b = 2

c = a/b

print(c)
# Out:
# 0.5

# %%
a = 10
b = 3

c = a/b 

print(c)
# Out:
# 3.3333333333333335

# %%
a = 10
b = 3

c = a//b  #FLOOR DIV

print(c)
# Out:
# 3

# %%
a = 10
b = 2

c = a%b #MODULUS

print(c)
# Out:
# 0

# %% [markdown]
# ## COMPARISION OP

# %%
print(3>2)
# Out:
# True

# %%
print(3==2)
# Out:
# False

# %%
print(3 != 10)
# Out:
# True

# %%
print(3 >= 10)
# Out:
# False

# %%
a = 8

a
# Out:
# 8

# %% [markdown]
# ## LOGICAL OP

# %%
print(3>2 and 3>7)
# Out:
# False

# %%
print(3>2 or 3>7)
# Out:
# True

# %%
print(not(3>2 or 3>7))
# Out:
# False

# %%
print(not(3>2 and 3>7))
# Out:
# True

# %% [markdown]
# ## IDENTITY OP

# %%
a = 1234
b = 1234

print(a is b)
# Out:
# False

# %%
a = 1234
b = "1234"

print(a is b)
# Out:
# False

# %%
a = 1234
b = "1234"

print(a is not b)
# Out:
# True

# %% [markdown]
# ## MEMBERSHIP OP

# %%
a = "salman khan"

print("m" in a)
# Out:
# True

# %%
a = "salman khan"

print("m" not in a)
# Out:
# False

# %% [markdown]
# ## IDENTITY OP

# %%
marks = 97

# %%
if marks >= 90:
    print("BETA TUM HUSHAR HO")
    
print("THANKYOU")
# Out:
# BETA TUM HUSHAR HO
# THANKYOU

# %%
marks = 80

if marks >= 90:
    print("BETA TUM HUSHAR HO")
else:
    print("BETA TUM ZIDAGI ME AGE JAOGE")
    
print("THANKYOU")
# Out:
# BETA TUM ZIDAGI ME AGE JAOGE
# THANKYOU

# %%
marks = int(input("BETA KITNE AAYE?  "))


if marks >= 90:
    print("BETA TUM HUSHAR HO")
    
elif marks >= 80 and marks < 90:
    print("BETA TUM ZIDAGI ME AGE JAOGE")
    
elif marks >= 70 and marks < 80:
    print("BETA TUM YOUTUBER BANO")    
    
else:
    print("TUM UPSC CRACK KARO")
# Out:
# BETA KITNE AAYE?  66
# TUM UPSC CRACK KARO
