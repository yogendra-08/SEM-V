# %%
from nltk.utils import ngrams

text = "Natural Language Processing (NLP) is an area of computer science"

n = 1

uni = ngrams(text.split(), n)
for grams in uni:
    print(grams)
