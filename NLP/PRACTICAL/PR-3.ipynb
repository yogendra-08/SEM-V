# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')

text = "welcome to the department of information technology"

print(text)
print(text.split(" "))
print(len(text.split(" ")))

print(nltk.word_tokenize(text))
print(len(nltk.word_tokenize(text)))
